# %%
# Include this line to make plots interactive
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
nl_metadata_path = "data/nl_data_df.csv"

nl_data = pd.read_csv(nl_metadata_path)
nl_data

#get rid of stn
#set index to date
#format the date
# Out:
#        STN      DATE  24HR average temp C  Max low temp C  Max high temp C  \
# 0      260  19010101                  -49             -65              -24
# 1      260  19010102                  -18             -33              -14
# 2      260  19010103                  -26             -76               -6
# 3      260  19010104                  -65             -90              -11
# 4      260  19010105                  -60             -82              -20
# ...    ...       ...                  ...             ...              ...
# 43651  260  20200706                  149             101              183
# 43652  260  20200707                  146              80              192
# 43653  260  20200708                  146             129              169
# 43654  260  20200709                  167             147              177
# 43655  260  20200710                  146              82              185
#
#       Sunshine duration in hours
# 0                             28
# ...

# %%
nl_data['DATE'] = pd.to_datetime(nl_data['datetime_column']).dt.date

df['date_column'] = pd.to_datetime(df['datetime_column']).dt.date
#nl_data.set_index('DATE')

#covert string to date pandas
# Out:
#                                STN  24HR average temp C  Max low temp C  \
# DATE
# 1970-01-01 00:00:00.019010101  260                  -49             -65
# 1970-01-01 00:00:00.019010102  260                  -18             -33
# 1970-01-01 00:00:00.019010103  260                  -26             -76
# 1970-01-01 00:00:00.019010104  260                  -65             -90
# 1970-01-01 00:00:00.019010105  260                  -60             -82
# ...                            ...                  ...             ...
# 1970-01-01 00:00:00.020200706  260                  149             101
# 1970-01-01 00:00:00.020200707  260                  146              80
# 1970-01-01 00:00:00.020200708  260                  146             129
# 1970-01-01 00:00:00.020200709  260                  167             147
# 1970-01-01 00:00:00.020200710  260                  146              82
#
#                                Max high temp C Sunshine duration in hours
# DATE
# ...

# %%
mean_temp_list= nl_data["24HR average temp C"]
mean_temp_list
# Out:
# 0        -49
# 1        -18
# 2        -26
# 3        -65
# 4        -60
#         ...
# 43651    149
# 43652    146
# 43653    146
# 43654    167
# 43655    146
# Name: 24HR average temp C, Length: 43656, dtype: int64

# %%
max_low_list= nl_data["Max low temp C"]
max_low_list
# Out:
# 0        -65
# 1        -33
# 2        -76
# 3        -90
# 4        -82
#         ...
# 43651    101
# 43652     80
# 43653    129
# 43654    147
# 43655     82
# Name: Max low temp C, Length: 43656, dtype: int64

# %%
max_high_list= nl_data["Max high temp C"]
max_high_list
# Out:
# 0        -24
# 1        -14
# 2         -6
# 3        -11
# 4        -20
#         ...
# 43651    183
# 43652    192
# 43653    169
# 43654    177
# 43655    185
# Name: Max high temp C, Length: 43656, dtype: int64

# %%
print(nl_data["DATE"])
# Out:
# 0        19010101
# 1        19010102
# 2        19010103
# 3        19010104
# 4        19010105
#            ...
# 43651    20200706
# 43652    20200707
# 43653    20200708
# 43654    20200709
# 43655    20200710
# Name: DATE, Length: 43656, dtype: int64

# %%
years= (nl_data["DATE"])
years
# Out:
# 0        19010101
# 1        19010102
# 2        19010103
# 3        19010104
# 4        19010105
#            ...
# 43651    20200706
# 43652    20200707
# 43653    20200708
# 43654    20200709
# 43655    20200710
# Name: DATE, Length: 43656, dtype: int64

# %%
# Plot the world average as a line chart
temp_avg, = plt.plot(years, mean_temp_list, color="blue", label="Mean_Temp" )

# Plot the low values 
temp_low, = plt.plot(years, max_low_list, color="green",label="Low_Temp")

# Plot the high values
temp_high, = plt.plot(years, max_high_list, color="red",label="Low_Temp")

# Create a legend 
plt.legend(handles=[temp_avg, temp_low, temp_high], loc="best")

# Show the chart
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">
